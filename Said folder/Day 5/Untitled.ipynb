# %%
import matplotlib.pyplot as plt
import seaborn as sns

yuekd_apples = [0.895, 0.91,0.919,0.926, 0.929, 0.895]

years = [2010, 2011, 2012, 2013, 2014, 2015]
plt.plot(years , yuekd_apples)

# %%
sns.barplot(x='day' , y='total_bill', data=tips_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11340\1234428033.py in <module>
# ----> 1 sns.barplot(x='day' , y='total_bill', data=tips_df)
#
# NameError: name 'tips_df' is not defined
